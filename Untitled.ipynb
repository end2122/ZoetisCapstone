# %%
import pandas as pd

# %%
df = pd.read_csv('./df_ABR.csv', index_col=0)
df.head()
# Out:
#           Drug  Treated  Repulls  Mortalities  Treatment Success(%)  \
# 1     300PROLA        0      0.0          0.0                  0.00
# 2         A180        0      0.0          0.0                  0.00
# 3  A180As2ndRx        0      0.0          0.0                  0.00
# 4       Adspec        0      0.0          0.0                  0.00
# 5      Advocin      142     23.0         14.0                  0.84
#
#    Case Fatality Rate(%)  $/Hd/Rx  Treatment $    Month  Year Risk Season  \
# 1                    0.0     0.00         0.00  January  2018  Low  Other
# 2                    0.0     0.00         0.00  January  2018  Low  Other
# 3                    0.0     0.00         0.00  January  2018  Low  Other
# 4                    0.0     0.00         0.00  January  2018  Low  Other
# 5                    0.1    36.13      5130.82  January  2018  Low  Other
#
#      Datetime
# 1  2018-01-01
# 2  2018-01-01
# 3  2018-01-01
# 4  2018-01-01
# 5  2018-01-01

# %%
df['moving'] = df.groupby('Risk')['Treatment $'].transform(lambda x: x.rolling(1, 1).mean())

# %%
df[df['Risk']=='Low']
# Out:
#                     Drug  Treated  Repulls  Mortalities  Treatment Success(%)  \
# 1               300PROLA        0      0.0          0.0                  0.00
# 2                   A180        0      0.0          0.0                  0.00
# 3            A180As2ndRx        0      0.0          0.0                  0.00
# 4                 Adspec        0      0.0          0.0                  0.00
# 5                Advocin      142     23.0         14.0                  0.84
# 6         AdvocinAs2ndRx      716      1.0        118.0                  1.00
# 7             AlbonBolus        0      0.0          0.0                  0.00
# 8                Baytril        4      4.0          1.0                  0.00
# 9         BaytrilAs2ndRx     1128      1.0        112.0                  1.00
# 10        BaytrilAs3rdRx        9      2.0          3.0                  0.78
# 11             Bio-Mycin       36     12.0          5.0                  0.67
# ...

# %%
df.info()
df.shape
df['Risk'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3789 entries, 1 to 33
# Data columns (total 13 columns):
# Drug                     3789 non-null object
# Treated                  3789 non-null int64
# Repulls                  3789 non-null float64
# Mortalities              3789 non-null float64
# Treatment Success(%)     3789 non-null float64
# Case Fatality Rate(%)    3789 non-null float64
# $/Hd/Rx                  3789 non-null float64
# Treatment $              3789 non-null float64
# Month                    3789 non-null object
# Year                     3789 non-null int64
# Risk                     3789 non-null object
# Season                   3789 non-null object
# Datetime                 3789 non-null object
# dtypes: float64(6), int64(2), object(5)
# memory usage: 414.4+ KB
# array(['Low', 'Natural', 'Moderate', 'High', 'UltraHigh'], dtype=object)

# %%
df.sort_values('Month')[df['Risk']=='Low Risk']['Pulls']
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 31    689.0
# 1     400.0
# 13    553.0
# 25    763.0
# 43    811.0
# 37    561.0
# 61    540.0
# 7     476.0
# 67    508.0
# 55    558.0
# 49    592.0
# 19    715.0
# 79    481.0
# 73    519.0
# Name: Pulls, dtype: float64
